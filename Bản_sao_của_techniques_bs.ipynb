# %% [markdown]
# <a href="https://colab.research.google.com/github/anhduc02/anhduc02/blob/main/B%E1%BA%A3n_sao_c%E1%BB%A7a_techniques_bs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 Tải 1 url về

# %%
import requests
import urllib.request
from bs4 import BeautifulSoup



url = 'https://www.24h.com.vn/'
r = urllib.request.urlopen(url) #, allow_redirects=True)
print(r)

#open('24h.duc', 'wb').write(r.content)
watch_html = BeautifulSoup(r , 'html.parser')

# %% [markdown]
# 2. Lưu 1 html vào thư mục chỉ định

# %%
file = open('file' +'.html','w')
file.write(watch_html.text)
file.close()

# %% [markdown]
# 3. Cách lấy 1 phần tử đầu tiên ra khỏi list và xóa nó khỏi list

# %%
list_a = [1, 2, 3, 4]
print("Trước khi xóa:",list_a)
list_b=list_a.pop(0)
print("Sau khi xóa:",list_a)
# Out:
# Trước khi xóa: [1, 2, 3, 4]
# Sau khi xóa: [2, 3, 4]

# %% [markdown]
# 4. Cách lấy các url trong html

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 

html = urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# https://www.24h.com.vn/bong-da-c48.html
# https://www.24h.com.vn/kinh-doanh-c161.html
# https://www.24h.com.vn/thi-truong-tieu-dung-c52.html
# https://www.24h.com.vn/suc-khoe-doi-song-c62.html
# https://www.24h.com.vn/thoi-trang-hi-tech-c407.html
# https://www.24h.com.vn/doi-song-showbiz-c729.html
# https://www.24h.com.vn/tin-tuc-quoc-te-c415.html
# https://eva.vn/
# https://www.24h.com.vn/the-thao-c101.html
# https://www.24h.com.vn/bong-da-ngoai-hang-anh-c149.html
# https://www.24h.com.vn/lich-van-nien-c936.html
# javascript:void(0);
# /
# #
# https://www.24h.com.vn/tin-tuc-trong-ngay-c46.html
# https://www.24h.com.vn/dich-covid-19-c62e6058.html
# https://www.24h.com.vn/su-kien-noi-bat-24h-c46e4872.html
# https://www.24h.com.vn/tin-tuc-trong-ngay/chiec-ngai-vang-doc-nhat-con-lai-o-viet-nam-c46a1216747.html
# https://www.24h.com.vn/tin-tuc-trong-ngay/chiec-ngai-vang-doc-nhat-con-lai-o-viet-nam-c46a1216747.html
# https://www.24h.com.vn/24h-van-dam-c46e6104.html
# ...
