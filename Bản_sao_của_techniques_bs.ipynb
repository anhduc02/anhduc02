# %% [markdown]
# <a href="https://colab.research.google.com/github/anhduc02/anhduc02/blob/main/B%E1%BA%A3n_sao_c%E1%BB%A7a_techniques_bs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 Tải 1 url về

# %%
import requests
import urllib.request
from bs4 import BeautifulSoup



url = 'https://www.24h.com.vn/'
r = urllib.request.urlopen(url) #, allow_redirects=True)
print(r)

#open('24h.duc', 'wb').write(r.content)
watch_html = BeautifulSoup(r , 'html.parser')
print(watch_html)
# Out:
# <http.client.HTTPResponse object at 0x7f7c0faccf28>
# <!DOCTYPE html>
#
# <html lang="vi" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <link href="https://image-us.24h.com.vn/upload/icon/icon_24h.ico" rel="SHORTCUT ICON" type="image/x-icon"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=yes" name="viewport">
# <title>Tin tức bóng đá, thể thao, giải trí | Đọc tin tức 24h mới nhất</title>
# <meta content="Tin tức 24h về bóng đá, thể thao, giải trí. Tin tức online 24 giờ, tình hình Việt Nam(VN), thế giới. Xem video bóng đá tổng hợp tại 24h." name="description"/>
# <meta content="tin tức 24h, tin tuc 24h, tin tuc trong ngay, bóng đá, thời trang, cười, tintuc, 24h, tin nhanh , the thao, tin nhanh, thoi trang, thời sự, bong da, bao cong an, bao an ninh, thoi su, giai tri, giải trí, bao" itemprop="keywords" name="keywords"/>
# <meta content="tin tức 24h, tin tuc 24h, tin tuc trong ngay, bóng đá, thời trang, cười, tintuc, 24h, tin nhanh , the thao, tin nhanh, thoi trang, thời sự, bong da, bao cong an, bao an ninh, thoi su, giai tri, giải trí, bao" name="news_keywords"/>
# <link href="https://www.24h.com.vn/" rel="canonical"/><link href="https://amp.24h.com.vn/" rel="amphtml"/>
# <meta content="index,follow,noodp" name="robots"/><meta content="noarchive" name="robots"/>
# <meta content="Tin tức 24h" property="og:site_name">
# <meta content="Website" property="og:type"/>
# <meta content="vi_VN" property="og:locale"/>
# <meta content="232505114857147" property="fb:app_id"/>
# <meta content="1128104117285467" property="fb:pages"/>
# <meta content="Tin tức bóng đá, thể thao, giải trí | Đọc tin tức 24h mới nhất" itemprop="name" property="og:title"/>
# <meta content="https://www.24h.com.vn/" itemprop="url" property="og:url"/>
# <meta content="Tin tức 24h về bóng đá, thể thao, giải trí. Tin tức online 24 giờ, tình hình Việt Nam(VN), thế giới. Xem video bóng đá tổng hợp tại 24h." property="og:description"/><meta content="https://image-us.24h.com.vn/upload/2-2018/images/2018-06-14/logo-chan-trang-24h.png" itemprop="thumbnailUrl" property="og:image"/>
# <!--script_breadcrum-->
# <!-- HOME_INDEX_24H -->
# <!--Snippets Video Google-->
# <!--@meta_googlebot@-->
# <!--Schema_video-->
# <meta content="vi" http-equiv="Content-Language"/>
# <meta content="vi" name="Language"/>
# <meta content="Copyright © 2013 by 24H.COM.VN" name="copyright"/>
# <meta content="24H.COM.VN Website tin tức số 1 Việt Nam" name="abstract"/>
# <meta content="Global" name="distribution"/>
# <meta content="Tin Tức 24h" name="author"/>
# <meta content="1200" http-equiv="refresh"/>
# <meta content="1 DAYS" name="REVISIT-AFTER"/>
# <meta content="GENERAL" name="RATING"/>
# <script src="//static-us.24h.com.vn/js/24hgatracking/fe/prod/24huidutil.min.js"></script><script type="text/javascript">
#     var uId24H = 'profile24hUid';
#     var gauID24h_dimension31 = '';
#     function get24hUidData(name) {
#       const value = `; ${document.cookie}`;
#       const parts = value.split(`; ${name}=`);
#       if (parts.length === 2) return parts.pop().split(';').shift();
#     }
#     gauID24h_dimension31 = get24hUidData(uId24H);
#     if(gauID24h_dimension31 === ''){
#         gauID24h_dimension31 = 'None';
#     }
# </script>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://adver-us.24h.com.vn/" rel="dns-prefetch"/>
# <link href="https://static-us.24h.com.vn/" rel="dns-prefetch"/>
# <link href="https://image-us.24h.com.vn/" rel="dns-prefetch"/>
# <link href="https://video-us.24h.com.vn/" rel="dns-prefetch"/>
# <link href="https://anh.24h.com.vn/" rel="dns-prefetch"/>
# <script type="application/ld+json">
# {
#   "@context" : "http://schema.org",
#   "@type" : "Organization",
#   "name" : "Tin tức 24h",
#   "url" : "https://www.24h.com.vn/",
#   "logo": "https://static-us.24h.com.vn/images/m2014/images/logo-24h_bookmarks.png"
# }
# </script><!--meta_ants-->
# <!--@meta_data_add_28_08_2015@-->
# <style>@charset "utf-8";*{font-family:Arial,Helvetica,sans-serif;font-size:12px}body{margin:0}a{text-decoration:none}a:hover{color:#78b43d}p{line-height:1.4}img{border:0}.clF,.clear{clear:both}.contnr{margin:0 auto;width:1004px;background:#fff}.footerd .contnr{width:100%}*html .contnr{overflow:hidden}.mrB20{margin-bottom:20px}.mrT20{margin-top:20px}.mrT15{margin-top:15px}.mrT10{margin-top:10px}.mrT5{margin-top:5px}.mrB5{margin-bottom:5px}.mrL10{margin-left:10px}.mrR10{margin-right:10px}.mrB10{margin-bottom:10px}.mrB15{margin-bottom:15px}.pdB20{padding-top:20px}.pdT20{padding-top:20px}.pdB10{padding-bottom:10px}.pdT10{padding-top:10px}.pdT5{padding-top:5px}.pdB5{padding-bottom:5px}.clrWh{color:#fff}.clrGr{color:#757575}.clrGrn{color:#00722e}.clrBlu{color:#00f}.clrTit{color:#333}.txtIl{font-style:italic}.txtCt p > *{font-size:13px}.hdr{width:100%;position:initial;height:50px;background:#78b43d;margin:0 auto;background-attachment:scroll!important}.log{float:left;width:90px;height:50px;overflow:hidden;position:relative}.mnTp{width:70px;float:left;border-left:#90c95a solid 1px;border-right:#90c95a solid 1px;height:38px;padding:12px 0 0 10px}h1,h2,h3,h4,h5,h6{margin:0;display:inline}ul,li{margin:0;padding:0;list-style:none}.m_banner_show{display:block;margin:0 auto}#rightBannerBackground .m_banner_show{text-align:left}#leftBannerBackground .m_banner_show{text-align:right}.picIco{position:absolute;display:block;bottom:5px;left:5px;background:url(//static-us.24h.com.vn/images/sprites092018.png) no-repeat -50px -4391px;width:24px;height:24px;z-index:1}.icoPic{background:url(//static-us.24h.com.vn/images/2014/icon-pic.gif) no-repeat 5px 0;width:20px;height:9px;display:inline-block}.vdNml{background:url(//static-us.24h.com.vn/images/sprites092018.png) no-repeat -50px -359px}.lstNml{background:url(//static-us.24h.com.vn/images/sprites092018.png) no-repeat -46px -253px}.viHt{background:url(//static-us.24h.com.vn/images/sprites092018.png) no-repeat -50px -680px}.phtNml{background:url(//static-us.24h.com.vn/images/sprites092018.png) no-repeat -50px -1549px}.phtHt{background:url(//static-us.24h.com.vn/images/2014/photo_hot.png) 0 6px no-repeat;background-size:11px}.lstRdStr{background:url(//static-us.24h.com.vn/images/sprites092018.png) no-repeat -51px -2323px}.icoquz{background:url(//static-us.24h.com.vn/images/2014/icon-quiz.png) 0 5px no-repeat}.icoNws{background:url(//static-us.24h.com.vn/images/sprites092018.png) no-repeat -50px -2551px;width:29px;height:12px;vertical-align:-2px;display:inline-block;margin:0 0 0 5px}.vidIcoLt{position:absolute;display:block;bottom:5px;left:5px;background:url(//static-us.24h.com.vn/images/sprites092018.png) no-repeat -50px -4515px;width:24px;height:24px;z-index:1}.icoVid{background:url(//static-us.24h.com.vn/images/m2014/images-small/iconVideo-small.png) no-repeat 3px 0;width:21px;height:10px;margin-left:2px;display:inline-block}.icoInfo{background:url(//static-us.24h.com.vn/images/sprites092018.png) no-repeat -50px -1328px}.icoMaz{background:url(//static-us.24h.com.vn/images/sprites092018.png) no-repeat -50px -2100px}.redStar{background:url(//static-us.24h.com.vn/images/2014/red-star.gif) 0 0 no-repeat;width:10px;height:10px;margin-left:2px;display:inline-block}.grnStar{background:url(//static-us.24h.com.vn/images/2014/green-star.gif) 0 0 no-repeat;width:10px;height:10px;margin-left:2px;display:inline-block}.icoLiv{display:inline-block;color:#fff;font-size:7px;line-height:12px;position:relative;top:-1px;text-transform:uppercase;font-weight:600;background:red;padding:0 3px;border-radius:3px;margin-left:5px}.txtCent{text-align:center}.txtRt{text-align:right}.arPagUp{display:block;z-index:9999999;position:fixed;bottom:20px;right:20px;opacity:.6;transition:background .3s,color .3s;-webkit-transition:background .3s,color .3s;-moz-transition:background .3s,color .3s}#back-to-top.show{opacity:1;width:40px;height:40px;display:inline-block;background-size:40px}#back-to-top{opacity:0}.arPagUp:hover{opacity:.7}.txt ...
# <!--@css_quizz3_news@-->
# <!--@css_twentytwenty@-->
# <!--@css_magazine@-->
# <!--@js_magazine@-->
# <script type="text/javascript">
# 				function f_get_clientWidth(){return f_get_filterResults(window.innerWidth?window.innerWidth:0,screen.width?screen.width:0)}function f_get_clientHeight(){return f_get_filterResults(window.innerHeight?window.innerHeight:0,screen.availHeight?screen.availHeight:0)}function f_get_filterResults(d,a){var b=d?d:0;return a&&!b?a:b}
# 				// Khai báo biến
# 				var v_client_width = parseInt(f_get_clientWidth());
# 				var v_client_height = parseInt(f_get_clientHeight());
# 				var v_client_screen = parseInt(v_client_width*v_client_height);
# 				var v_client_screen_min = 823246;
# 				var v_client_width_min = 1420;
# 				var v_client_width_min_size_nho = 1279;
# 				var v_show_define_slot = document.cookie.indexOf("v_close_banner_sticky=");
# 			</script>
# <script type="text/javascript">
#         var onOffTargetingCococ = 1;
#         var keyTargetingCococ = 'browser_types';
#         var valueTargetingCococ = 'coc_coc';
#         function setTargetingDefineSlotWithCoccocBrower(){if(-1<navigator.userAgent.toLowerCase().indexOf("coc_coc_browser")&&0<onOffTargetingCococ&&"undefined"!=typeof slots&&0<Object.keys(slots).length)for(var a in slots)slots[a].setTargeting(keyTargetingCococ,[valueTargetingCococ])}
#     </script>
# <!--@@start_code_prebid-->
# <script async="async" src="https://image-us.24h.com.vn/upload/24h_js_library/prebid3.27.1_24h_us.js?v=20200410"></script><script>var pbjs,HB_TIMEOUT=1e3,PREBID_TIMEOUT=HB_TIMEOUT,CRITEO_CDB_TIMEOUT=HB_TIMEOUT,n_adserver_callback=0,sendAdserverRequest=function(){++n_adserver_callback<2||pbjs.adserverRequestSent||(pbjs.adserverRequestSent=!0,googletag.cmd.push(function(){pbjs.que.push(function(){pbjs.setTargetingForGPTAsync(),"undefined"!=typeof Criteo&&"function"==typeof Criteo.SetDFPKeyValueTargeting&&Criteo.SetDFPKeyValueTargeting(),setTimeout(function(){googletag.pubads().refresh()},100)})}))};</script>
# <script>var adUnits=[{code:"div-gpt-ad-1490323067809-4",mediaTypes:{banner:{sizes:[[300,600]]}},bids:[{bidder:"rubicon",params:{accountId:"17516",siteId:"172696",zoneId:"841804"}},{bidder:"ix",params:{siteId:"359606",size:[300,600]}},{bidder:"smartadserver",params:{domain:"//prg3431.smartadserver.com",siteId:"300919",pageId:"1100142",formatId:"80213"}},{bidder:"pubmatic",params:{publisherId:"157376",adSlot:"24H_Half1_300x600@300x600"}},{bidder:"criteo",params:{networkId:"3785"}}]},{code:"div-gpt-ad-1490323067809-6",mediaTypes:{banner:{sizes:[[300,600]]}},bids:[{bidder:"rubicon",params:{accountId:"17516",siteId:"172696",zoneId:"841810"}},{bidder:"ix",params:{siteId:"360426",size:[300,600]}},{bidder:"smartadserver",params:{domain:"//prg3431.smartadserver.com",siteId:"300919",pageId:"1100142",formatId:"80215"}},{bidder:"pubmatic",params:{publisherId:"157376",adSlot:"24H_Half3_300x600@300x600"}},{bidder:"criteo",params:{networkId:"3785"}}]},{code:"div-gpt-ad-1490323067809-7",mediaTypes:{banner:{sizes:[[300,250],[336,280]]}},bids:[{bidder:"rubicon",params:{accountId:"17516",siteId:"172696",zoneId:"841812"}},{bidder:"ix",params:{siteId:"360427",size:[300,250]}},{bidder:"smartadserver",params:{domain:"//prg3431.smartadserver.com",siteId:"300919",pageId:"1100142",formatId:"80216"}},{bidder:"pubmatic",params:{publisherId:"157376",adSlot:"24H_Hot1_300x250@300x250"}},{bidder:"criteo",params:{networkId:"3785"}}]},{code:"div-gpt-ad-1490323067809-11",mediaTypes:{banner:{sizes:[[160,600]]}},bids:[{bidder:"rubicon",params:{accountId:"17516",siteId:"172696",zoneId:"841800"}},{bidder:"ix",params:{siteId:"360428",size:[160,600]}},{bidder:"smartadserver",params:{domain:"//prg3431.smartadserver.com",siteId:"300919",pageId:"1100142",formatId:"80217"}},{bidder:"pubmatic",params:{publisherId:"157376",adSlot:"24H_Background_left_160x600@160x600"}},{bidder:"criteo",params:{networkId:"3785"}}]},{code:"div-gpt-ad-1490323067809-12",mediaTypes:{banner:{sizes:[[160,600]]}},bids:[{bidder:"rubicon",params:{accountId:"17516",siteId:"172696",zoneId:"841802"}},{bidder:"ix",params:{siteId:"360429",size:[160,600]}},{bidder:"smartadserver",params:{domain:"//prg3431.smartadserver.com",siteId:"300919",pageId:"1100142",formatId:"80218"}},{bidder:"pubmatic",params:{publisherId:"157376",adSlot:"24H_Background_right_160x600@160x600"}},{bidder:"criteo",params:{networkId:"3785"}}]}],pbjs=pbjs||{};pbjs.que=pbjs.que||[];var googletag=googletag||{};googletag.cmd=googletag.cmd||[],googletag.cmd.push(function(){googletag.pubads().disableInitialLoad()}),pbjs.que.push(function(){pbjs.setConfig({priceGranularity:"dense",userSync:{filterSettings:{iframe:{bidders:"*",filter:"include"}}},consentManagement:{cmpApi:"iab",timeout:1e3,allowAuctionWithoutConsent:!0}}),pbjs.addAdUnits(adUnits),pbjs.requestBids({bidsBackHandler:sendAdserverRequest})}),setTimeout(function(){sendAdserverRequest()},PREBID_TIMEOUT);</script>
# <!--@@end_code_prebid-->
# <!--@@start_code_criteo-->
# <script src="//static.criteo.net/js/ld/publishertag.js" type="text/javascript"></script> <!--@@end_code_criteo-->
# <!--@@START_SCRIPT_DFP-->
# <script async="async" src="//www.googletagservices.com/tag/js/gpt.js"></script>
# <script type="text/javascript">
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         (function() {
#         var gads = document.createElement('script');
#         gads.async = true;
#         gads.type = 'text/javascript';
#         var useSSL = 'https:' == document.location.protocol;
#         gads.src = (useSSL ? 'https:' : 'http:') +
#         '//www.googletagservices.com/tag/js/gpt.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(gads, node);
#         })();
#     </script>
# <script type="text/javascript">
# 		var slots = {};
# 		googletag.cmd.push(function() {
# 		slots['skyleft']=googletag.defineSlot('/124557882/24h/us/desktop/home/skyleft', [[298, 900], [160, 600]], 'div-gpt-ad-1490323067809-11').addService(googletag.pubads());slots['skyleft'].setTargeting('id_div', 'div-gpt-ad-1490323067809-11');
#
# slots['half1']=googletag.defineSlot('/124557882/24h/us/desktop/home/half1', [[300, 600],[300, 250]], 'div-gpt-ad-1490323067809-4').addService(googletag.pubads());slots['half1'].setTargeting('id_div', 'div-gpt-ad-1490323067809-4');
#
#
# slots['half3']=googletag.defineSlot('/124557882/24h/us/desktop/home/half3', [300, 600], 'div-gpt-ad-1490323067809-6').addService(googletag.pubads());slots['half3'].setTargeting('id_div', 'div-gpt-ad-1490323067809-6');
#
# slots['center']=googletag.defineSlot('/124557882/24h/us/desktop/home/center', [[696, 120], [696, 86]], 'div-gpt-ad-1490323067809-1').addService(googletag.pubads());slots['center'].setTargeting('id_div', 'div-gpt-ad-1490323067809-1');
#
#
# slots['hotrectangle1']=googletag.defineSlot('/124557882/24h/us/desktop/home/hotrectangle1', [[300, 250], [336, 280]], 'div-gpt-ad-1490323067809-7').addService(googletag.pubads());slots['hotrectangle1'].setTargeting('id_div', 'div-gpt-ad-1490323067809-7');
#
# slots['skyright']=googletag.defineSlot('/124557882/24h/us/desktop/home/skyright', [[298, 901], [160, 600]], 'div-gpt-ad-1490323067809-12').addService(googletag.pubads());slots['skyright'].setTargeting('id_div', 'div-gpt-ad-1490323067809-12');
#
#
# 		googletag.pubads().enableSingleRequest();
# 		googletag.pubads().collapseEmptyDivs();
# 		googletag.pubads().enableVideoAds();
# 		googletag.companionAds().setRefreshUnfilledSlots(true);
# 		googletag.enableServices();
# 		});
# 	</script>
# <!--@@END_SCRIPT_DFP--><script>
# 	var amazonSlots=[{slotID:"div-gpt-ad-1490323067809-4",slotName:"/124557882/24h/us/desktop/home/half1",sizes:[[300,600]]},{slotID:"div-gpt-ad-1490323067809-6",slotName:"/124557882/24h/us/desktop/home/half3",sizes:[[300,600]]},{slotID:"div-gpt-ad-1490323067809-7",slotName:"/124557882/24h/us/desktop/home/hotrectangle1",sizes:[[300,250]]},{slotID:"div-gpt-ad-1490323067809-11",slotName:"/124557882/24h/us/desktop/home/skyleft",sizes:[[160,600]]},{slotID:"div-gpt-ad-1490323067809-12",slotName:"/124557882/24h/us/desktop/home/skyright",sizes:[[160,600]]}];!function(e,a,t,s,o,i,n){function d(t,s){a[e]._Q.push([t,s])}a[e]||(a[e]={init:function(){d("i",arguments)},fetchBids:function(){d("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]},(i=t.createElement(s)).async=!0,i.src="//c.amazon-adsystem.com/aax2/apstag.js",(n=t.getElementsByTagName(s)[0]).parentNode.insertBefore(i,n))}("apstag",window,document,"script"),apstag.init({pubID:"f6d4f034-e95c-4b38-a823-9ad23ced8869",adServer:"googletag"}),apstag.fetchBids({slots:amazonSlots,timeout:1e3},function(t){googletag.cmd.push(function(){apstag.setDisplayBids()})});
# </script>
# <script type="text/javascript">
#     //setParamGaContentVideoNews
# 	v_cat_id = 45;
# </script>
# <script type="text/javascript">v_arr_cau_hinh_thu_tu_quang_cao_video = ['Pre-roll'];</script><script type="text/javascript">
#     window.addEventListener('load', function(){
#         _setStorageJson24h('pageCookie', ++pageCookie, 720);
#     });
# </script>
# <!-- Begin comScore Tag -->
# <script type="text/javascript">
# 	//<![CDATA[
# 		  var _comscore = _comscore || [];
# 		  _comscore.push({ c1: "2", c2: "9634358" });
# 		  (function() {
# 			var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# 			s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# 			el.parentNode.insertBefore(s, el);
# 		  })();
# 	//]]>
# 	</script>
# <!-- End comScore Tag -->
# <!-- Begin GA code -->
# <script type="text/javascript">//<![CDATA[
# 		(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 				  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 				  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 				  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# 	ga('create', 'UA-2286909-2','auto', {'useAmpClientId': true});
#     ga('require', 'linker');
#     ga('linker:autoLink', ['24h.vn', '24gio.com.vn']);
#     ga('require', 'displayfeatures');
# 	ga('set', 'contentGroup1', 'Home');
# 							ga('set', 'contentGroup2', 'None');
# 							ga('set', 'contentGroup3', 'desktop');
# 							ga('set', 'contentGroup4', 'home');
#                             ga('set', 'contentGroup5', 'null');
#     ga('send', 'pageview',{'dimension1':'Home', 'dimension2':'None', 'dimension3':'desktop','dimension4':'home','dimension31':gauID24h_dimension31});
#             	//]]>
# 	</script>
# <!-- End GA code -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-24EL5B93N8"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-24EL5B93N8');
#     </script>
# <script type="text/javascript">//<![CDATA[
#                 if(typeof(gauID24h_dimension31) == 'undefined'){
#                     var gauID24h_dimension31 = 'None';
#                 }
#                 gtag('event', 'content_group',
#                 {
#                         pageType_24h:'Home',
#                         pageEmbed_24h:'None',
#                         pagePlatform_24h:'desktop',
#                         pageCategory_24h:'home',
#                         categoryId_24h:'45',
#                         pageContentGroup_24h:'null',
#                         gauID24h_24h:gauID24h_dimension31,
#                 });
#             //]]></script>
# <!--html_rss_feed-->
# <script type="text/javascript">
# 			var v_mode_gen_banner_old = 2;
# 		</script><style>@charset "UTF-8";.video-js .vjs-big-play-button .vjs-icon-placeholder:before,.video-js .vjs-modal-dialog,.vjs-button>.vjs-icon-placeholder:before,.vjs-modal-dialog .vjs-modal-dialog-content{position:absolute;top:0;left:0;width:100%;height:100%}.video-js .vjs-big-play-button .vjs-icon-placeholder:before,.vjs-button>.vjs-icon-placeholder:before{text-align:center}@font-face{font-family:VideoJS;src:url(data:application/font-woff;charset=utf-8;base64,...) format("woff");font-weight:400;font-style:normal}.video-js .vjs-big-play-button .vjs-icon-placeholder:before,.video-js .vjs-play-control .vjs-icon-placeholder,.vjs-icon-play{font-family:VideoJS;font-weight:400;font-style:normal}.video-js .vjs-big-play-button .vjs-icon-placeholder:before,.video-js .vjs-play-control .vjs-icon-placeholder:before,.vjs-icon-play:before{content:"\f101"}.vjs-icon-play-circle{font-family:VideoJS;font-weight:400;font-style:normal}.vjs-icon-play-circle:before{content:"\f102"}.video-js .vjs-play-control.vjs-playing .vjs-icon-placeholder,.vjs-icon-pause{font-family:VideoJS;font-weight:400;font-style:normal}.video-js .vjs-play-control.vjs-playing .vjs-icon-placeholder:before,.vjs-icon-pause:before{content:"\f103"}.video-js .vjs-mute-control.vjs-vol-0 .vjs-icon-placeholder,.vjs-icon-volume-mute{font-family:VideoJS;font-weight:400;font-style:normal}.video-js .vjs-mute-control.vjs-vol-0 .vjs-icon-placeholder:before,.vjs-icon-volume-mute:before{content:"\f104"}.video-js .vjs-mute-control.vjs-vol-1 .vjs-icon-placeholder,.vjs-icon-volume-low{font-family:VideoJS;font-weight:400;font-style:normal}.video-js .vjs-mute-control.vjs-vol-1 .vjs-icon-placeholder:before,.vjs-icon-volume-low:before{content:"\f105"}.video-js .vjs-mute-control.vjs-vol-2 .vjs-icon-placeholder,.vjs-icon-volume-mid{font-family:VideoJS;font-weight:400;font-style:normal}.video-js .vjs-mute-control.vjs-vol-2 .vjs-icon-placeholder:before,.vjs-icon-volume-mid:before{content:"\f106"}.video-js .vjs-mute-control .vjs-icon-placeholder,.vjs-icon-volume-high{font-family:VideoJS;font-weight:400;font-style:normal}.video-js .vjs-mute-control .vjs-icon-placeholder:before,.vjs-icon-volume-high:before{content:"\f107"}.video-js .vjs-fullscreen-control .vjs-icon-placeholder,.vjs-icon-fullscreen-enter{font-family:VideoJS;font-weight:400;font-style:normal}.video-js .vjs-fullscreen-control .vjs-icon-placeholder:before,.vjs-icon-fullscreen-enter:before{content:"\f108"}.video-js.vjs-fullscreen .vjs-fullscreen-control .vjs-icon-placeholder,.vjs-icon-fullscreen-exit{font-family:VideoJS;font-weight:400;font-style:normal}.video-js.vjs-fullscreen .vjs-fullscreen-control .vjs-icon-placeholder:before,.vjs-icon-fullscreen-exit:before{content:"\f109"}.vjs-icon-square{font-family:VideoJS;font-weight:400;font-style:normal}.vjs-icon-square:before{content:"\f10a"}.vjs-icon-spinner{font-family:VideoJS;font-weight:400;font-style:normal}.vjs-icon-spinner:before{content:"\f10b"}.video-js .vjs-subs-caps-button .vjs-icon-placeholder,.video-js .vjs-subtitles-button .vjs-icon-placeholder,.video-js.video-js:lang(en-AU) .vjs-subs-caps-button .vjs-icon-placeholder,.video-js.video-js:lang(en-GB) .vjs-subs-caps-button .vjs-icon-placeholder,.video-js.video-js:lang(en-IE) .vjs-subs-caps-button .vjs-icon-placeholder,.video-js.video-js:lang(en-NZ) .vjs-subs-caps-button .vjs-icon-placeholder,.vjs-icon-subtitles{font-family:VideoJS;font-weight:400;font-style:normal}.video-js .vjs-subs-caps-button .vjs-icon-placeholder:before,.video-js .vjs-subtitles-button .vjs-icon-placeholder:before,.video-js.video-js:lang(en-AU) .vjs-subs-caps-button .vjs-icon-placeholder:before,.video-js.video-js:lang(en-GB) .vjs-subs-caps-button .vjs-icon-placeholder:before,.video-js.video-js:lang(en-IE) .vjs-subs-caps-button .vjs-icon-placeholder:before,.video-js.video-js:lang(en-NZ) .vjs-subs-caps-button .vjs-icon-placeholder:before,.vjs-icon-subtitles:before{content:"\f10c"}.video-js .vjs-captions-button .vjs-icon-placeholder,.video-js:lang(en) .vjs-subs-caps-b ...
# <body style="background:url('https://static-us.24h.com.vn/images/2014/bg.jpg') repeat-x"><!--@@SCRIPT_GTM_BODY@@--><div id="background_bg_link"></div><!-- HEADER:START --> <!-- no delete (Danh dau de thay the trang anh)-->
# <div id="wrapperd">
# <!-- Start Header -->
# <header class="hdr" id="headerd">
# <!-- Start menu right -->
# <nav class="hdrRt">
# <div class="contnr">
# <script type="text/javascript">
#     v_arr_html_menu_c2_header = '';// khởi tạo biến
# </script>
# <div class="tpMnRt tpMnRtx">
# <ul>
# <li class="rlt" onmouseout="showHideMenuHorizontalHeader(0,48, 'div_menu_c2_header_48');" onmouseover="showHideMenuHorizontalHeader(1,48, 'div_menu_c2_header_48');">
# <a href="https://www.24h.com.vn/bong-da-c48.html" title="Bóng đá">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/4-2018/images/2018-11-05/icons8-soccer-ball-96-copy-1541383138-270-width20height20.png"/></span>
# <span class="tit">Bóng đá</span>
# </a>
# <div class="mnC2Hdr mnC2" id="div_menu_c2_header_48"></div>
# </li>
# <li class="rlt" onmouseout="showHideMenuHorizontalHeader(0,161, 'div_menu_c2_header_161');" onmouseover="showHideMenuHorizontalHeader(1,161, 'div_menu_c2_header_161');">
# <a href="https://www.24h.com.vn/kinh-doanh-c161.html" title="Kinh doanh">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/4-2018/images/2018-11-05/icons8-increase-96-copy-1541383138-358-width19height19.png"/></span>
# <span class="tit">Kinh doanh</span>
# </a>
# <div class="mnC2Hdr mnC2" id="div_menu_c2_header_161"></div>
# </li>
# <li class="rlt" onmouseout="showHideMenuHorizontalHeader(0,52, 'div_menu_c2_header_52');" onmouseover="showHideMenuHorizontalHeader(1,52, 'div_menu_c2_header_52');">
# <a href="https://www.24h.com.vn/thi-truong-tieu-dung-c52.html" title="Thị trường - Tiêu dùng">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/4-2018/images/2018-11-05/thitruong-1541409305-47-width20height18.png"/></span>
# <span class="tit">Thị trường</span>
# </a>
# <div class="mnC2Hdr mnC2" id="div_menu_c2_header_52"></div>
# </li>
# <li class="rlt" onmouseout="showHideMenuHorizontalHeader(0,62, 'div_menu_c2_header_62');" onmouseover="showHideMenuHorizontalHeader(1,62, 'div_menu_c2_header_62');">
# <a href="https://www.24h.com.vn/suc-khoe-doi-song-c62.html" title="Sức khỏe đời sống">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/4-2018/images/2018-11-05/heartbeat1-1541383138-349-width20height18.png"/></span>
# <span class="tit">Sức khỏe</span>
# </a>
# <div class="mnC2Hdr mnC2" id="div_menu_c2_header_62"></div>
# </li>
# <li class="rlt" onmouseout="showHideMenuHorizontalHeader(0,407, 'div_menu_c2_header_407');" onmouseover="showHideMenuHorizontalHeader(1,407, 'div_menu_c2_header_407');">
# <a href="https://www.24h.com.vn/thoi-trang-hi-tech-c407.html" title="Thời trang Hi-tech">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/4-2018/images/2018-11-05/icons8-smartphone-tablet-52-copy-1541383138-560-width20height20.png"/></span>
# <span class="tit">Hi-tech</span>
# </a>
# <div class="mnC2Hdr mnC2" id="div_menu_c2_header_407"></div>
# </li>
# <li class="rlt" onmouseout="showHideMenuHorizontalHeader(0,729, 'div_menu_c2_header_729');" onmouseover="showHideMenuHorizontalHeader(1,729, 'div_menu_c2_header_729');">
# <a href="https://www.24h.com.vn/doi-song-showbiz-c729.html" title="Đời sống Showbiz">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/4-2018/images/2018-11-05/icons8-christmas-star-96-1541383138-392-width20height20.png"/></span>
# <span class="tit">Showbiz</span>
# </a>
# <div class="mnC2Hdr mnC2" id="div_menu_c2_header_729"></div>
# </li>
# <li class="rlt" onmouseout="showHideMenuHorizontalHeader(0,415, 'div_menu_c2_header_415');" onmouseover="showHideMenuHorizontalHeader(1,415, 'div_menu_c2_header_415');">
# <a href="https://www.24h.com.vn/tin-tuc-quoc-te-c415.html" title="Thế giới">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/4-2018/images/2018-11-05/icons8-globe-962-1541383138-743-width20height20.png"/></span>
# <span class="tit">Thế giới</span>
# </a>
# <div class="mnC2Hdr mnC2" id="div_menu_c2_header_415"></div>
# </li>
# <li class="rlt">
# <a href="https://eva.vn/" rel="nofollow" target="_blank" title="Phái đẹp">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/4-2018/images/2018-11-05/avatar-copy-1541383138-498-width16height20.png"/></span>
# <span class="tit">Phái đẹp</span>
# </a>
# </li>
# <li class="rlt" onmouseout="showHideMenuHorizontalHeader(0,101, 'div_menu_c2_header_101');" onmouseover="showHideMenuHorizontalHeader(1,101, 'div_menu_c2_header_101');">
# <a href="https://www.24h.com.vn/the-thao-c101.html" title="Thể thao">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/1-2020/images/2020-01-17/thethao-1579244755-985-width20height22.png"/></span>
# <span class="tit">Thể thao</span>
# </a>
# </li>
# <li class="rlt" onmouseout="showHideMenuHorizontalHeader(0,149, 'div_menu_c2_header_149');" onmouseover="showHideMenuHorizontalHeader(1,149, 'div_menu_c2_header_149');">
# <a href="https://www.24h.com.vn/bong-da-ngoai-hang-anh-c149.html" title="Bóng đá Ngoại hạng Anh">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/3-2019/images/2019-08-19/ngoai_hang_anh-1566185659-966-width20height20.png"/></span>
# <span class="siHot"></span>
# <span class="tit">Ngoại hạng Anh</span>
# </a>
# </li>
# <li class="rlt" onmouseout="showHideMenuHorizontalHeader(0,936, 'div_menu_c2_header_936');" onmouseover="showHideMenuHorizontalHeader(1,936, 'div_menu_c2_header_936');">
# <a href="https://www.24h.com.vn/lich-van-nien-c936.html" title="Lịch vạn niên">
# <span class="icoMenuTop"><img alt="" class="initial loaded" src="https://image-us.24h.com.vn/upload/2-2020/images/2020-06-15/xem-l---ch---pc-1592210544-394-width25height25.png"/></span>
# <span class="tit">Xem lịch</span>
# </a>
# </li>
# </ul>
# <div class="icoSch">
# <div class="frmGrp hsFedBck" id="icon_search">
# <a href="javascript:void(0);" onmouseover="header_append_search_box();">
# <span class="icoSearTop"></span>
# </a>
# </div>
# </div>
# <script type="text/javascript">
#         v_html_search = "\r\n    <form style=\"margin:0px;\" name=\"search_box\" id=\"search_box\" target=\"_blank\" action=\"\/\/www.google.com\/cse\">  \r\n        <input type=\"hidden\" value=\"015713360359124540288:broohx1xloo\" name=\"cx\"\/><input type=\"hidden\" value=\"UTF-8\" name=\"ie\"\/>\r\n        <input class=\"frmctrl\" id=\"search\" placeholder=\"Nh\u1eadp tin t\u1ee9c c\u1ea7n t\u00ecm\" type=\"text\" name=\"q\" spellcheck=\"false\" autocomplete=\"off\" value=\"Nh\u1eadp tin t\u1ee9c c\u1ea7n t\u00ecm\" onblur=\"javascript:if(this.value==''){this.value='Nh\u1eadp tin t\u1ee9c c\u1ea7n t\u00ecm'}\" onfocus=\"javascript:if(this.value=='Nh\u1eadp tin t\u1ee9c c\u1ea7n t\u00ecm'){this.value=''}\" \/>\r\n        <a href=\"javascript:void(0);\" onclick=\"document.search_box.submit();\"><span class=\"icoSearTop\"><\/span><\/a>\r\n    <\/form>";
#     </script>
# </div>
# </div>
# </nav>
# <!-- End menu right -->
# <!-- Start menu left -->
# <div class="contnr">
# <div class="log">
# <div class="hmClk logoOld">
# <h1> <a href="/" title="Tin tức bóng đá, thể thao, giải trí | Đọc tin tức 24h mới nhất">
# <img alt="Tin tức bóng đá, thể thao, giải trí | Đọc tin tức 24h mới nhất" src="https://static-us.24h.com.vn/images/2014/24h_logo_trang_chu_2015.png">
# </img></a>
# </h1> </div>
# </div>
# <script type="text/javascript">
#                 v_html_menu_trai = '';
#             </script>
# <div class="mnTp mnTpx">
# <ul class="nav navx">
# <li class="sbLi sbLix" onmouseout="showHideMenuLeft(0);" onmouseover="showHideMenuLeft(1);">
# <a class="sbA" href="#">Danh mục</a>
# <div class="mnTrhnr" id="zone_menu_trai_header"></div>
# </li>
# </ul>
# </div>
# </div>
# <!-- End menu left -->
# </header>
# <div class="atrHdr"></div>
# <div class="vjs-hidden" id="largePlayer"></div>
# <!--@banner_hot_oto@-->
# <!-- HEADER:END --><!-- Start Maincontent -->
# <div class="clF mrT10" id="maiContent">
# <div class="contnr">
# <!-- Start ColLeft -->
# <div class="colLt">
# <main id="left">
# <!-- end:breaking news -->
# <section class="bxDoL">
# <header class="bxDoT">
# <span class="grnTbL"></span><div class="grnTbR"><ul><li><h2><a href="https://www.24h.com.vn/tin-tuc-trong-ngay-c46.html" title="Tin tức trong ngày">Tin tức trong ngày</a></h2></li></ul></div>
# <span class="gryTbL"></span><div class="gryTbR"><ul><li><a href="https://www.24h.com.vn/dich-covid-19-c62e6058.html" title="Dịch COVID-19">Dịch COVID-19</a></li></ul></div>
# <span class="gryTbL"></span><div class="gryTbR"><ul><li><a href="https://www.24h.com.vn/su-kien-noi-bat-24h-c46e4872.html" title="Sự kiện nổi bật">Sự kiện nổi bật</a></li></ul></div>
# </header>
# <div class="bxDoC"> <article class="bxDoItspc" id="spec_box_tin_tuc_trong_ngay_bong_da_the_thao_2">
# <header class="nwsTit cltitbxbdtt" id="id_class_title_box_bd_tt_2">
# <a href="https://www.24h.com.vn/tin-tuc-trong-ngay/anh-tuyet-roi-phu-trang-y-ty-va-sa-pa-ngo-nhu-lac-buoc-o-troi-au-c46a1216465.html" style="font-size: 14px;" title="Ảnh: Tuyết rơi phủ trắng Y Tý và Sa Pa, ngỡ như lạc bước ở trời Âu">Ảnh: Tuyết rơi phủ trắng Y Tý và Sa Pa, ngỡ như lạc bước ở trời Âu</a>
# </header>
# <span class="imgFlt imgNwsHm"> <a class="cl_image_dai_dien_gif" href="https://www.24h.com.vn/tin-tuc-trong-ngay/anh-tuyet-roi-phu-trang-y-ty-va-sa-pa-ngo-nhu-lac-buoc-o-troi-au-c46a1216465.html" title="Ảnh: Tuyết rơi phủ trắng Y Tý và Sa Pa, ngỡ như lạc bước ở trời Âu"><img alt="Ảnh: Tuyết rơi phủ trắng Y Tý và Sa Pa, ngỡ như lạc bước ở trời Âu" class="width-100" data-original="https://image-us.24h.com.vn/upload/1-2021/images/2021-01-11/120x90/image_dai_dien_gifava1-1610344654-304-width640height480.jpg" src="..."/></a>
# </span>
# <span class="nwsSpSpc">Tuyết đã rơi phủ trắng mọi cảnh vật ở Y Tý và Sa Pa (Lào Cai), khung cảnh tuyệt đẹp khiến nhiều người ngỡ như đang lạc...</span> <div class="divSbNws"><a href="https://www.24h.com.vn/khong-khi-lanh-tang-cuong-c46e5218.html" title="Sự kiện: Không khí lạnh tăng cường">Không khí lạnh tăng cường</a></div>
# <div class="clF"></div>
# </article>
# <div class="hmNwsSpe2">
# <article class="lstNml">
# <span class="icoSpites"></span>
# <a href="https://www.24h.com.vn/tin-tuc-trong-ngay/trung-ta-csgt-hy-sinh-trong-luc-tuan-tra-tren-song-c46a1216542.html" title="Thông tin mới nhất về ca mắc COVID-19 tại Hà Nội sau 5 ngày thở máy">Thông tin mới nhất về ca mắc COVID-19 tại Hà Nội sau 5...</a>
# </article> <article class="lstNml">
# <span class="icoSpites"></span>
# <a href="https://www.24h.com.vn/tin-tuc-trong-ngay/dot-than-cui-suoi-am-chi-tu-vong-em-nguy-kich-c46a1216533.html" title="Đốt than củi sưởi ấm, chị tử vong, em nguy kịch">Đốt than củi sưởi ấm, chị tử vong, em nguy kịch</a>
# </article> <article class="lstNml">
# <span class="icoSpites"></span>
# <a href="https://www.24h.com.vn/tin-tuc-trong-ngay/chay-tiem-tap-hoa-ba-om-chau-bang-qua-bien-lua-luc-rang-sang-c46a1216498.html" title="Cháy tiệm tạp hóa, bà ôm cháu băng qua “biển lửa” lúc rạng sáng">Cháy tiệm tạp hóa, bà ôm cháu băng qua “biển lửa” lúc...</a>
# </article> </div>
# <div class="hmNwsSpe1">
# <article class="lstNml">
# <span class="icoSpites"></span>
# <a href="https://www.24h.com.vn/tin-tuc-trong-ngay/dao-co-thu-gia-tram-trieu-ra-pho-cho-dai-gia-ruoc-ve-nha-choi-tet-c46a1216303.html" title='Đào cổ thụ giá trăm triệu ra phố chờ đại gia "rước" về nhà chơi Tết'>Đào cổ thụ giá trăm triệu ra phố chờ đại gia...</a>
# </article> <article class="lstNml">
# <span class="icoSpites"></span>
# <a href="https://www.24h.com.vn/tin-tuc-quoc-te/vu-may-bay-indonesia-cho-62-nguoi-roi-thong-diep-cuoi-cung-cua-nan-nhan-c415a1216350.html" title="Vụ máy bay Indonesia chở 62 người rơi: Thông điệp cuối cùng của nạn nhân">Vụ máy bay Indonesia chở 62 người rơi: Thông điệp...</a>
# </article> </div>
# </div>
# </section>
# <section class="bxDoR">
# <header class="bxDoT">
# <span class="grnTbL"></span><div class="grnTbR"><ul><li><h2><a href="https://www.24h.com.vn/bong-da-c48.html" onclick="ga('send', 'event', 'nhan_box_bong_da_the_thao', 'click', 'chuyen_muc:48~~id_tin:NULL~~phien_ban:pc', {nonInteraction: true});" title="Bóng đá">Bóng đá</a></h2></li></ul></div>
# <span class="gryTbL"></span><div class="gryTbR"><ul><li><a href="https://www.24h.com.vn/the-thao-c101.html" onclick="ga('send', 'event', 'nhan_box_bong_da_the_thao', 'click', 'chuyen_muc:101~~id_tin:NULL~~phien_ban:pc', {nonInteraction: true});" title="Thể thao">Thể thao</a></li></ul></div>
# <span class="gryTbL"></span><div class="gryTbR"><ul><li><a href="https://www.24h.com.vn/video-ban-thang-c297.html" title="Video">Video</a></li></ul></div>
# <span class="gryTbL"></span><div class="gryTbR"><ul><li><a href="https://www.24h.com.vn/bong-da-ngoai-hang-anh-c149.html" title="Ngoại hạng Anh">Ngoại hạng Anh</a></li></ul></div>
# <span class="gryTbL"></span><div class="gryTbR"><ul><li><a href="https://www.24h.com.vn/lich-thi-dau-bong-da/lich-thi-dau-bong-da-hom-nay-c287a364371.html" title="Lịch thi đấu">Lịch thi đấu</a></li></ul></div>
# </header>
# <div class="bxDoC"> <article class="bxDoItspc" id="spec_box_tin_tuc_trong_ngay_bong_da_the_thao_3">
# <header class="nwsTit cltitbxbdtt" id="id_class_title_box_bd_tt_3">
# <a href="https://www.24h.com.vn/bong-da/mu-hung-huc-dau-burnley-de-vuot-liverpool-cavani-tai-xuat-maguire-da-cap-sao-tre-c48a1216365.html" style="font-size: 14px;" title="MU hừng hực đấu Burnley để vượt Liverpool: Cavani tái xuất, Maguire đá cặp SAO trẻ">MU hừng hực đấu Burnley để vượt Liverpool: Cavani tái xuất, Maguire đá cặp SAO trẻ</a>
# </header>
# <span class="imgFlt imgNwsHm"><span class="vidIcoLt"></span> <a href="https://www.24h.com.vn/bong-da/mu-hung-huc-dau-burnley-de-vuot-liverpool-cavani-tai-xuat-maguire-da-cap-sao-tre-c48a1216365.html" title="MU hừng hực đấu Burnley để vượt Liverpool: Cavani tái xuất, Maguire đá cặp SAO trẻ"><img alt="MU hừng hực đấu Burnley để vượt Liverpool: Cavani tái xuất, Maguire đá cặp SAO trẻ" class="width-100" data-original="https://image-us.24h.com.vn/upload/1-2021/images/2021-01-11/120x90/rtrtytr-1610331639-312-width640height480.jpg" src="..."/></a>
# </span>
# <span class="nwsSpSpc">HLV Solskjaer cập nhật tình hình lực lượng của MU trước cuộc đối đầu Burnley.</span> <div class="divSbNws"><a href="https://www.24h.com.vn/manchester-united-c48e1521.html" title="Sự kiện: Manchester United">Manchester United</a></div>
# <div class="clF"></div>
# </article>
# <div class="hmNwsSpe2">
# <article class="vdNml">
# <span class="icoSpites"></span>
# <a href="https://www.24h.com.vn/bong-da/mu-liverpool-dua-vo-dich-quy-do-thuc-su-manh-hay-chi-ao-tuong-c48a1215819.html" title='MU - Liverpool đua vô địch: "Quỷ đỏ" thực sự mạnh hay chỉ ảo tưởng?'>MU - Liverpool đua vô địch: "Quỷ đỏ" thực sự mạnh hay...</a>
# </article> <article class="vdNml">
# <span class="icoSpites"></span>
# <a href="https://www.24h.com.vn/bong-da/video-juventus-sassuolo-11-dau-10-van-kho-so-buoc-ngoat-phut-82-c48a1216325.html" title="Video Juventus - Sassuolo: 11 đấu 10 vẫn khổ sở, bước ngoặt phút 82">Video Juventus - Sassuolo: 11 đấu 10 vẫn khổ sở, bước...</a>
# </article> <article class="vdNml">
# <span class="icoSpites"></span>
# <a href="https://www.24h.com.vn/bong-da/ngoai-hang-anh-truoc-chang-leo-nui-mu-thach-thuc-liverpool-ong-lon-rinh-co-hoi-c48a1216408.html" title='Ngoại hạng Anh trước chặng "leo núi": MU thách thức Liverpool, "ông lớn" rình cơ hội'>Ngoại hạng Anh trước chặng "leo núi": MU thách thức...</a>
# </article> </div>
# <div class="hmNwsSpe1">
# <article class="vdNml">
# <span class="icoSpites"></span>
# <a href="https://www.24h.com.vn/bong-da/ronaldo-san-bang-ky-luc-ban-thang-chinh-thuc-nhieu-nhat-trong-lich-su-c48a1216328.html" title="Ronaldo san bằng kỷ lục bàn thắng chính thức nhiều nhất trong lịch sử">Ronaldo san bằng kỷ lục bàn thắng chính thức...</a>
# </article> <article class="lstNml">
# <span class="icoSpites"></span>
# <a href="https://www.24h.com.vn/the-thao/5-nu-vdv-hay-dang-anh-do-mat-my-nhan-bong-chuyen-lep-ve-kieu-nu-golf-c101a1216002.html" title="5 nữ VĐV hay đăng ảnh “đỏ mặt”: Mỹ nhân bóng chuyền “lép vế” kiều nữ golf">5 nữ VĐV hay đăng ảnh “đỏ mặt”: Mỹ nhân bóng...</a>
# </article> </div>
# </div>
# </section>
# <div class="clF"></div>
# <section class="txtCent pdB5 bnrPtn" id="ADS_143_15s_container"><div class="" id="ADS_143_15s"><script type="text/javascript">
# 									window.addEventListener("load",function() {
# 										if (typeof(ADS_143_15s.aNodes) != "undefined" && ADS_143_15s.aNodes.length > 0) {
# 											banner_tostring(ADS_143_15s,"ADS_143_15s");
# 										} else {
# 											document.getElementById("ADS_143_15s_container").style.display = "none";
#
# 										}
# 									})
# 							    </script>
# </div>
# </section><section class="bxDoR mrB10">
# <header class="bxDoT"> <span class="grnTbL"></span>
# <div class="grnTbR"><ul><li> <a href="https://www.24h.com.vn/kinh-doanh-c161.html" title="Kinh doanh">Kinh doanh</a> </li></ul>
# </div> <span class="gryTbL"></span>
# <div class="gryTbR"><ul><li> <a href="https://www.24h.com.vn/tai-chinh-c587.html" title="Tài chính">Tài chính</a> </li></ul>
# </div> <span class="gryTbL"></span>
# <div class="gryTbR"><ul><li> <a href="https://www.24h.com.vn/bat-dong-san-c792.html" title="Bất động sản">Bất động sản</a> </li></ul>
# </div> <span class="gryTbL"></span>
# <div class="gryTbR"><ul><li> <a href="https://www.24h.com.vn/doanh-nghiep-c849.html" title="Doanh nghiệp">Doanh nghiệp</a> </li></ul>
# </div> </header>
# <div class="bxDoC">
# <article class="bxDoIt">
# <header class="nwsTit titbxdoitrangchu"><a href="https://www.24h.com.vn/kinh-doanh/verosa-park-khang-dien-gan-1000-khach-tham-du-su-kien-tri-an-sac-hoa-bung-sang-c161a1216352.html" rel="sponsored" style="font-size: 14px;" title="Verosa Park - Khang Điền: Gần 1000 khách tham dự sự kiện tri ân “Sắc hoa bừng sáng”">Verosa Park - Khang Điền: Gần 1000 khách tham dự sự kiện tri ân “Sắc hoa bừng...</a></header>
# <span class="imgFlt imgNwsHm">
# <a href="https://www.24h.com.vn/kinh-doanh/verosa-park-khang-dien-gan-1000-khach-tham-du-su-kien-tri-an-sac-hoa-bung-sang-c161a1216352.html" rel="sponsored" title="Verosa Park - Khang Điền: Gần 1000 khách tham dự sự kiện tri ân “Sắc hoa bừng sáng”"><img alt="Verosa Park - Khang Điền: Gần 1000 khách tham dự sự kiện tri ân “Sắc hoa bừng sáng”" class="width-100" data-original="https://image-us.24h.com.vn/upload/1-2021/images/2021-01-11/120x90/ava-1610329215-199-width640height480.jpg" src="..."/></a>
# </span>
# <span class="nwsSpSpc">Ngày 9.1.2021, Khang Điền đã tổ chức chương trình “Sắc hoa bừng sáng” tại Verosa  Park, thu hút gần 1000 lượt khách...</span>
# <div class="clF"></div>
# </article>
# <div class="bxDoMrNws"> <article class="lstNml"><span class="icoSpites"></span><a href="https://www.24h.com.vn/toi-tieu-tien/bi-quyet-lam-giau-5000-nam-tuoi-cua-han-quoc-den-nay-nhieu-ty-phu-van-ap-dung-c851a1215076.html" style="line-height: 16px;" title="Bí quyết làm giàu 5000 năm tuổi của Hàn Quốc, đến nay nhiều tỷ phú vẫn áp dụng">Bí quyết làm giàu 5000 năm tuổi của Hàn Quốc, đến nay...</a></article> <article class="phtNml"><span class="icoSpites"></span><a href="https://www.24h.com.vn/bat-dong-san/nhung-cong-trinh-dat-vang-o-chau-a-viet-nam-co-toi-3-dai-dien-c792a1215831.html" style="line-height: 16px;" title="Đại gia Việt Nam không kém cạnh đại gia Dubai, chịu chơi dát vàng cả tòa nhà">Đại gia Việt Nam không kém cạnh đại gia Dubai, chịu...</a></article> <article class="lstNml"><span class="icoSpites"></span><a href="https://www.24h.com.vn/gia-vang-hom-nay/gia-vang-gom-nay-11-1-tiep-da-lao-xuong-day-c425a1216354.html" style="line-height: 16px;" title="Giá vàng hôm nay 11/1: Tiếp đà lao xuống đáy">Giá vàng hôm nay 11/1: Tiếp đà lao xuống đáy</a></article> <article class="lstNml"><span class="icoSpites"></span><a href="https://www.24h.com.vn/kinh-doanh/jack-ma-va-nhung-ty-phu-tung-dot-nhien-mat-tich-tai-trung-quoc-c161a1216290.html" style="line-height: 16px;" title="Jack Ma và những tỷ phú từng đột nhiên mất tích tại Trung Quốc">Jack Ma và những tỷ phú từng đột nhiên mất tích tại...</a></article>
# </div>
# </div>
# </section>
# <section class="bxDoL mrB10">
# <header class="bxDoT"> <span class="grnTbL"></span>
# <div class="grnTbR"><ul><li><h2> <a href="https://www.24h.com.vn/thoi-trang-c78.html" title="Thời trang">Thời trang</a></h2> </li></ul>
# </div> <span class="gryTbL"></span>
# <div class="gryTbR"><ul><li> <a href="https://www.24h.com.vn/bi-quyet-mac-dep-c272.html" title="Bí quyết mặc đẹp">Bí quyết mặc đẹp</a> </li></ul>
# </div> <span class="gryTbL"></span>
# <div class="gryTbR"><ul><li> <a href="https://www.24h.com.vn/nguoi-mau-hoa-hau-c214.html" title="Người mẫu - Hoa hậu">Người mẫu - Hoa hậu</a> </li></ul>
# </div> </header>
# <div class="bxDoC">
# <article class="bxDoIt">
# <header class="nwsTit titbxdoitrangchu"><a href="https://www.24h.com.vn/xu-huong-thoi-trang/nhung-chiec-quan-khoa-than-gay-tranh-cai-tiep-tay-cho-van-nan-quay-roi-phu-nu-c215a1216227.html" style="font-size: 14px;" title='Những chiếc quần "khỏa thân" gây tranh cãi "tiếp tay" cho vấn nạn quấy rối phụ nữ'>Những chiếc quần "khỏa thân" gây tranh cãi "tiếp tay" cho vấn nạn quấy rối phụ nữ</a></header>
# <span class="imgFlt imgNwsHm">
# <span class="picIco"></span> <a href="https://www.24h.com.vn/xu-huong-thoi-trang/nhung-chiec-quan-khoa-than-gay-tranh-cai-tiep-tay-cho-van-nan-quay-roi-phu-nu-c215a1216227.html" title='Những chiếc quần "khỏa thân" gây tranh cãi "tiếp tay" cho vấn nạn quấy rối phụ nữ'><img alt='Những chiếc quần "khỏa thân" gây tranh cãi "tiếp tay" cho vấn nạn quấy rối phụ nữ' class="width-100" data-original="https://image-us.24h.com.vn/upload/1-2021/images/2021-01-10/120x90/untitled-1dde-1610267916-32-width640height480.jpg" src="..."/></a>
# </span>
# <span class="nwsSpSpc">Chiếc quần legging gây nên tranh cãi "có tội" hay "vô tội" khi xảy ra những vụ quấy rối phụ nữ?.</span> <div class="divSbNws"><a href="https://www.24h.com.vn/phiem-chuyen-thoi-trang-c78e651.html" title="Sự kiện: Phiếm chuyện thời trang">Phiếm chuyện thời trang</a></div>
# <div class="clF"></div>
# </article>
# <div class="bxDoMrNws"> <article class="lstNml"><span class="icoSpites"></span><a href="https://www.24h.com.vn/xu-huong-thoi-trang/nang-quyen-gay-soc-khi-mac-trang-phuc-vuon-khong-nha-trong-giua-dam-dong-c215a1216305.html" style="line-height: 16px;" title='"Nàng Quyên" gây sốc khi mặc trang phục "vườn không nhà trống" tại sinh nhật bạn trai'>"Nàng Quyên" gây sốc khi mặc trang phục "vườn không...</a></article> <article class="lstNml"><span class="icoSpites"></span><a href="https://www.24h.com.vn/xu-huong-thoi-trang/9-xu-huong-giay-noi-bat-duoc-mong-doi-cho-mua-xuan-he-2021-c215a1216488.html" style="line-height: 16px;" title="9 xu hướng giày nổi bật được mong đợi cho mùa xuân hè 2021">9 xu hướng giày nổi bật được mong đợi cho mùa xuân hè...</a></article> <article class="lstNml"><span class="icoSpites"></span><a href="https://www.24h.com.vn/nguoi-mau-hoa-hau/le-quyen-dien-dam-do-ruc-kim-cuong-lap-lanh-tren-tham-do-thoi-trang-hung-dong-c214a1216425.html" style="line-height: 16px;" title='Lệ Quyên diện đầm đỏ rực, kim cương lấp lánh trên thảm đỏ thời trang "Hừng Đông"'>Lệ Quyên diện đầm đỏ rực, kim cương lấp lánh trên...</a></article> <article class="vdNml"><span class="icoSpites"></span><a href="https://www.24h.com.vn/bi-quyet-mac-dep/mac-nguoc-ao-len-va-cai-ket-bat-ngo-c272a1216442.html" style="line-height: 16px;" title="Mặc ngược áo len và cái kết bất ngờ">Mặc ngược áo len và cái kết bất ngờ</a></article>
# </div>
# </div>
# </section>
# <div class="clF pdB5"></div>
# <div class="divBnrHm mrB10">
# <section class="" id="ADS_145_15s_container"><div class="txtBnrHor">
# <span></span>
# </div><div class=" bnrHmL" id="ADS_145_15s">
# <!-- BEGIN 1460852 - 24H Group - VN - Adblocking - 300x250 - collapse -->
# <div id="Crt-1460852" style="height: 250px; width: 300px;"></div>
# <script type="text/javascript">
#                 Criteo.events.push(function() {
#                     Criteo.DisplayAcceptableAdIfAdblocked({
#                         "zoneid": 1460852,
#                         "containerid": "Crt-1460852",
#                         "overrideZoneFloor": false
#                     });
#                 });
#             </script>
# <script type="text/javascript">
#             window.addEventListener( "message",
#                 function (e) {
# ...
#         window['myLazyLoad'] = new LazyLoad({
#             data_src : 'original'
#         });
#     </script>
# <script type="text/javascript">
#         var uProfileMapping = Object.create(uProfileMapping); // initiate tracking object
#         uProfileMapping.uIdNamespace = uId24H;
# 		uProfileMapping.getIpUri = 'https://www.24h.com.vn/ip.php';
#         uProfileMapping.init(function(data){
#         });
#     </script>
# <script async="" src="https://static-us.24h.com.vn/js/jquery.min.js?v=0601202121" type="text/javascript"></script>
# <script async="" src="https://static-us.24h.com.vn/js/common_092018_pc.min.js?v=0601202121"></script><script async="" src="https://static-us.24h.com.vn/js/24h-092018-load-sau-pc.min.js?v=0601202121"></script>
# <!--@js_quizz3_news@-->
# <!--@js_twentytwenty@-->
# <!--@@JS_BOX_ANH_THUMNAIL@@-->
# <!--@@JS_gia_vang@@-->
# <script>function Banner(t){this.obj=t,this.aNodes=[],this.bNodes=[],this.currentBanner=0,this.intLoopCount=1,this.intBannerFix=-1,this.intBannerLong=0,this.stopShow=!1}function Node(t,e,n,r,o,i,s,a,u,c){this.name=t,this.bannerType=e,this.bannerPath=n,this.bannerDuration=r,this.height=o,this.width=i,this.hyperlink=s,this.position=a,this.popup=u,this.impression=c}function Node2(t,e,n,r,o,i,s,a){this.name=t,this.bannerType=e,this.bannerPath=n,this.bannerDuration=r,this.height=o,this.width=i,this.hyperlink=s,this.position=a}function NodeRich(t,e,n,r,o,i,s,a,u,c,h,f){this.name=t,this.bannerType=e,this.bannerPath=n,this.bannerDuration=r,this.height=o,this.width=i,this.height2=s,this.width2=a,this.type=u,this.name1=c,this.name2=h,this.desc=f}function d_Banner2(t){this.obj=t,this.aNodes=[],this.bNodes=[],this.currentBanner=0}function d_Banner(t){this.obj=t,this.aNodes=[],this.currentBanner=0}function dFloat_Banner(t){this.obj=t,this.aNodes=[],this.currentBanner=0}function Banner2(t){this.obj=t,this.aNodes=[],this.currentBanner=0,this.intLoopCount=0,this.intBannerFix=-1,this.stopShow=!1}function Node3(t,e,n,r,o,i,s,a,u){this.name=t,this.bannerType=e,this.bannerPath=n,this.bannerDuration=r,this.height=o,this.width=i,this.hyperlink=s,this.desc=a,this.popup=u}Banner.prototype.add=function(t,e,n,r,o,i,s,a,u){this.aNodes[this.aNodes.length]=new Node(this.obj+"_"+this.aNodes.length,t,e,n,r,o,i,"",a,u)},Banner.prototype.add2=function(t,e,n,r,o,i,s,a){this.bNodes[this.bNodes.length]=new Node(this.obj+"_"+this.bNodes.length,t,e,n,r,o,i,s,a)},Banner.prototype.add3=function(t,e,n,r,o,i,s,a,u,c){this.aNodes[this.aNodes.length]=new NodeRich(this.obj+"_"+this.aNodes.length,t,e,n,r,o,i,s,a,u,c)},d_Banner2.prototype.add=function(t,e,n,r,o,i,s){this.aNodes[this.aNodes.length]=new Node(this.obj+"_"+this.aNodes.length,t,e,0,n,r,o,i,s)},d_Banner2.prototype.add2=function(t,e,n,r,o,i,s){this.bNodes[this.bNodes.length]=new Node2(this.obj+"_b_"+this.bNodes.length,t,e,0,n,r,o,i,s)},d_Banner2.prototype.add3=function(t,e,n,r,o,i,s,a,u,c,h){this.aNodes[this.aNodes.length]=new NodeRich(this.obj+"_"+this.aNodes.length,t,e,0,r,o,i,s,a,u,c,h)},d_Banner2.prototype.add4=function(t,e,n,r,o,i,s,a,u,c,h){this.aNodes[this.bNodes.length]=new NodeRich(this.obj+"_"+this.aNodes.length,t,e,0,r,o,i,s,a,u,c,h)},d_Banner2.prototype.toString=function(){for(var t="",e=_get_stt_banner_hien_thi(pageCookie,this.aNodes.length),n=1,r=e;r<this.aNodes.length;r++){for(var o=0;o<this.bNodes.length;o++)n!=this.bNodes[o].position||(t+=genBanner(this.bNodes[o],"d_banner2_show"),n++);t+=genBanner(this.aNodes[r],"d_banner2_show"),n++}for(r=0;r<e;r++){for(o=0;o<this.bNodes.length;o++)n!=this.bNodes[o].position||(t+=genBanner(this.bNodes[o],"d_banner2_show"),n++);t+=genBanner(this.aNodes[r],"d_banner2_show"),n++}for(x=0;x<this.bNodes.length;x++)this.bNodes[x].position>=n&&(t+=genBanner(this.bNodes[x],"d_banner2_show"));return document.write(t),t=""},d_Banner.prototype.add=function(t,e,n,r,o,i,s){this.aNodes[this.aNodes.length]=new Node(this.obj+"_"+this.aNodes.length,t,e,0,n,r,o,"",i,s)},d_Banner.prototype.add2=function(t,e,n,r,o,i,s,a){this.bNodes[this.bNodes.length]=new Node(this.obj+"_"+this.bNodes.length,t,e,n,r,o,i,s,a)},d_Banner.prototype.add3=function(t,e,n,r,o,i,s,a,u,c,h){this.aNodes[this.aNodes.length]=new NodeRich(this.obj+"_"+this.aNodes.length,t,e,n,r,o,i,s,a,u,c,h)},d_Banner.prototype.toString=function(){for(var t="",e=_get_stt_banner_hien_thi(pageCookie,this.aNodes.length),n=e;n<this.aNodes.length;n++)t+=genBanner(this.aNodes[n],"d_banner_show");for(n=0;n<e;n++)t+=genBanner(this.aNodes[n],"d_banner_show");return document.write(t),t=""},dFloat_Banner.prototype.add=function(t,e,n,r,o,i){this.aNodes[this.aNodes.length]=new Node(this.obj+"_"+this.aNodes.length,t,e,0,n,r,o,i)},dFloat_Banner.prototype.toString=function(){for(var t="",e=_get_stt_banner_hien_thi(pageCookie,this.aNodes.length),n=e;n<this.aNodes.length;n++)t+=genBanner(this.aNodes[n],"d_Banner2_show");for(n=0;n<e;n++)t+=genBan ...
#     //<![CDATA[
#         var ADS_130_15s = new Banner('ADS_130_15s');
# var ADS_140_15s = new Banner('ADS_140_15s');
# ADS_140_15s.add( "SCRIPT", "<div id='div-gpt-ad-1490323067809-4' style='margin: 0 auto;'><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1490323067809-4'); });<\/script></div>", 20, 600, 300, "", '');
# var ADS_141_15s = new Banner('ADS_141_15s');
# var ADS_142_15s = new Banner('ADS_142_15s');
# ADS_142_15s.add( "SCRIPT", "<div id='div-gpt-ad-1490323067809-6' style=' margin: 0 auto;'><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1490323067809-6'); });<\/script></div>", 20, 600, 300, "", '');
# var ADS_143_15s = new Banner('ADS_143_15s');
# ADS_143_15s.add( "SCRIPT", "<div id='div-gpt-ad-1490323067809-1'><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1490323067809-1'); });<\/script></div>", 20, 120, 696, "", '');
# var ADS_144_15s = new Banner('ADS_144_15s');
# var ADS_145_15s = new Banner('ADS_145_15s');
# ADS_145_15s.add( "SCRIPT", "<div id='div-gpt-ad-1490323067809-7'><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1490323067809-7'); });<\/script></div>", 20, 280, 336, "", '');
# var ADS_146_15s = new Banner('ADS_146_15s');
# var ADS_147_15s = new Banner('ADS_147_15s');
# var ADS_148_15s = new Banner('ADS_148_15s');
# var ADS_149_15s = new Banner('ADS_149_15s');
# ADS_149_15s.add( "SCRIPT", "<div id='div-gpt-ad-1490323067809-11'><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1490323067809-11'); });<\/script></div>", 20, 600, 160, "", '');
# var ADS_150_15s = new Banner('ADS_150_15s');
# ADS_150_15s.add( "SCRIPT", "<div id='div-gpt-ad-1490323067809-12'><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1490323067809-12'); });<\/script></div>", 20, 600, 160, "", '');
# var ADS_152_15s = new Banner('ADS_152_15s');
# var ADS_153_15s = new Banner('ADS_153_15s');
# var ADS_154_15s = new Banner('ADS_154_15s');
# var ADS_155_15s = new Banner('ADS_155_15s');
# var ADS_159_15s = new Banner('ADS_159_15s');
# var ADS_139_15s = new Banner('ADS_139_15s');
# var ADS_200_15s = new Banner('ADS_200_15s');
# var ADS_201_15s = new Banner('ADS_201_15s');
# var ADS_202_15s = new Banner('ADS_202_15s');
# var ADS_203_15s = new Banner('ADS_203_15s');
# var ADS_204_15s = new Banner('ADS_204_15s');
# var ADS_205_15s = new Banner('ADS_205_15s');
# var ADS_206_15s = new Banner('ADS_206_15s');
# var ADS_207_15s = new Banner('ADS_207_15s');
#
#     //]]>
#                     var v_thoi_gian_luu_segment_target = 24; // Thời gian lưu trữ bằng giờ
#             var data_user_segment_set_target = _getStorageJson24h('data_user_segment_set_target');
#             var expire_user_segment_set_target = _getStorageJson24h('expire_user_segment_set_target');
#             var v_update_user_segment_target = false;
#             if(typeof(expire_user_segment_set_target) != 'undefined' && parseInt(expire_user_segment_set_target) > 0){
#                 if(expire_user_segment_set_target != v_thoi_gian_luu_segment_target){
#                     v_update_user_segment_target = true;
#                 }
#             }
#             if (!v_update_user_segment_target && typeof(data_user_segment_set_target) != 'undefined' && data_user_segment_set_target != '' && data_user_segment_set_target != null) {
#                 var data_clientid_user = _getStorageJson24h('data_clientid_user');
#                 console.log('data_user_segment_set_target_to_storage:'+data_user_segment_set_target);
#                 console.log('data_clientid_user_to_storage:'+data_clientid_user);
#                 googletag.cmd.push(function() {
#                     googletag.pubads().setTargeting('user_segment', data_user_segment_set_target);
#                 });
#             }else{
#                 ga(function (tracker) {
#                     var clientId_user = tracker.get('clientId');
#                     console.log('data_clientid_user:'+clientId_user);
#                     var v_ajax_url_get_type_user = 'https://search.24hstatic.com/v1/recommend/get_class_by_cliend_id?c_client_id=' + clientId_user+'&c_website=24h&b1';
#                     var xmlHttp = new GetXmlHttpObject();
#                     if (xmlHttp == null) {
#                         return;
#                     }
#                     xmlHttp.open("GET", v_ajax_url_get_type_user, true);
#                     xmlHttp.send(null);
#                     xmlHttp.onreadystatechange = function () {
#                         if ((xmlHttp.readyState == 4 || xmlHttp.readyState == 200) && xmlHttp.responseText != '') {
#                             var json_result = JSON.parse(xmlHttp.responseText);
#                             var list_user_segment = json_result.data.list_user_segment;
#                             var list_user_segment_set_target = json_result.data.list_user_segment_set_target;
#                             console.log('data_user_segment_set_target:'+list_user_segment_set_target);
#                             //var arr_type_user = new Array();
#                             //var type_user = json_result.data.type_user;
#                             //arr_type_user.push(clientId_user);
#                             //arr_type_user.push(type_user);
#                             //_setStorageJson24h('data_user_type', arr_type_user, new Date().getTime() + 1440*60 * 1000);
#                             //_setStorageJson24h('data_user_segment', list_user_segment, new Date().getTime() + 1440*60 * 1000);
#                             _setStorageJson24h('data_user_segment_set_target', list_user_segment_set_target, new Date().getTime() + 1440*60 * 1000);
#                             _setStorageJson24h('expire_user_segment_set_target', v_thoi_gian_luu_segment_target, new Date().getTime() + v_thoi_gian_luu_segment_target*60*60 * 1000);
#                             _setStorageJson24h('data_clientid_user', clientId_user, new Date().getTime() + v_thoi_gian_luu_segment_target*60*60 * 1000);
#                         }
#                     }
#                 });
#             }
#                 // Thực hiện tạo hiệu ứng banner cổng chào
#         window.addEventListener('load',function(){
#             show_effect_cong_chao_skip_ads();
#         });
#     </script>
# <div style="height:300px;"><script async="true" type="text/javascript">var elem=document.createElement("script");elem.src="https://quantcast.mgr.consensu.org/cmp.js",elem.async=!0,elem.type="text/javascript";var scpt=document.getElementsByTagName("script")[0];scpt.parentNode.insertBefore(elem,scpt),function(){function e(e){var t,o="string"==typeof e.data;if((t=o?-1!=e.data.indexOf("__cmpCall")?JSON.parse(e.data):{}:e.data).__cmpCall){var a=t.__cmpCall;window.__cmp(a.command,a.parameter,function(t,n){var c={__cmpReturn:{returnValue:t,success:n,callId:a.callId}};e.source.postMessage(o?JSON.stringify(c):c,"*")})}}!function e(){if(!window.frames.__cmpLocator)if(document.body){var t=document.body,o=document.createElement("iframe");o.style="display:none",o.name="__cmpLocator",t.appendChild(o)}else setTimeout(e,5)}(),window.__cmp=function(e){var t=arguments;if(!t.length)return __cmp.a;if("ping"===t[0])t[2]({gdprAppliesGlobally:!1,cmpLoaded:!1},!0);else{if("__cmp"==e)return!1;void 0===__cmp.a&&(__cmp.a=[]),__cmp.a.push([].slice.apply(t))}},window.__cmp.gdprAppliesGlobally=!1,window.__cmp.msgHandler=e,window.addEventListener?window.addEventListener("message",e,!1):window.attachEvent("onmessage",e)}(),window.__cmp("init",{Language:"en","Initial Screen Reject Button Text":"I do not accept","Initial Screen Accept Button Text":"I accept","Purpose Screen Body Text":"You can set your consent preferences and determine how you want your data to be used based on the purposes below. You may set your preferences for us independently from those of third-party partners. Each purpose has a description so that you know how we and partners use your data.","Vendor Screen Body Text":"You can set consent preferences for each individual third-party company below. Expand each company list item to see what purposes they use data for to help make your choices. In some cases, companies may disclose that they use your data without asking for your consent, based on their legitimate interests. You can click on their privacy policies for more information and to opt out.","Vendor Screen Accept All Button Text":"Accept all","Vendor Screen Reject All Button Text":"Reject all","Initial Screen Body Text":"We and our partners use technology such as cookies on our site to personalise content and ads, provide social media features, and analyse our traffic. Click below to consent to the use of this technology across the web. You can change your mind and change your consent choices at anytime by returning to this site.","Initial Screen Body Text Option":1,"Publisher Name":"24H ONLINE ADVERTISING JSC","Publisher Logo":"https://www.google.com/search?q=24H.com.vn+LOGO&amp;tbm=isch&amp;source=iu&amp;ictx=1&amp;fir=jIDQa1rhTJZLnM%253A%252Cho4IabzzDec-8M%252C_&amp;vet=1&amp;usg=AI4_-kR9-dBrCVdoOEajaeDRiv1xhzq1qw&amp;sa=X&amp;ved=2ahUKEwjmy8W04qniAhXQMd4KHWF6BzQQ9QEwB3oECAYQBA#imgrc=jIDQa1rhTJZLnM:","Consent Scope":"service","Post Consent Page":"https://www.24h.com.vn/","UI Layout":"banner","No Option":!1,"Publisher Purpose IDs":[1,2,3,4,5]});</script><style>.qc-cmp-alt-action,.qc-cmp-main-messaging,.qc-cmp-messaging,.qc-cmp-purpose-list,.qc-cmp-tab,.qc-cmp-vendor-list{font-size:10px!important}.qc-cmp-persistent-link{max-height:50px!important;height:40px!important;width:100px!important;padding:10px!important;min-width:30px}.qc-cmp-ui{max-height:230px;min-height:50px!important}</style></div>
# <!--END_OF_PAGE -->
# </div> <!-- /#wrapperd-->
# </div></body>
# </html><!--CACHE pc_trang_chu_092018-US-https-->

# %% [markdown]
# 2. Lưu 1 html vào thư mục chỉ định

# %% [markdown]
# 3. Cách lấy 1 phần tử đầu tiên ra khỏi list và xóa nó khỏi list

# %% [markdown]
# 4. Cách lấy các url trong html
